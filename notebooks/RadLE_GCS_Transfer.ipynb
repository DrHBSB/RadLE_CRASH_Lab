# %% [markdown]
# # RadLE v2 Colab-to-GCS Transfer
# This notebook mounts your Google Drive and syncs the frozen RadLE v2 image dataset to the `crashlab-synthetic` GCS bucket, bypassing local Windows limitations.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Authenticate/Set GCP Project
from google.colab import auth
auth.authenticate_user()
# !gcloud config set project crashlab-synthetic

# %%
# 3. Upload the frozen image folder to GCS (manuscript-clean destination)
# !gcloud storage rsync -r \
  "/content/drive/MyDrive/CRASH Lab/RaDLE/CONFIDENTIAL/RadLE v2 Dataset/RadLE v2 Master Data" \
  "gs://radle-medical-data-toronto/datasets/radle-v2-frozen-2026-06-29/RadLE v2 Master Data"

# %%
# 4. Verify the upload
# !gcloud storage ls "gs://radle-medical-data-toronto/datasets/radle-v2-frozen-2026-06-29/RadLE v2 Master Data/" | head
